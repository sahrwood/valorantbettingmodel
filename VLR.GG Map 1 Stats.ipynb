# %%
# pip3 install selenium

import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
s=Service(r'C:\Users\sahrw\OneDrive\Desktop\geckodriver.exe')

url=input("Enter match map link: ")
driver = webdriver.Firefox(service=s)
driver.get(url)

response=requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
results_page= BeautifulSoup(response.content, 'lxml')

CTRounds= results_page.find_all('span', class_= 'mod-ct')
TRounds= results_page.find_all('span', class_= 'mod-t')
# Team= results_page.find_all('div', class_='wf-title-med')
# Name= results_page.find_all('div', class_='text-of')
# Stats= results_page.find_all('span', class_='stats-sq')
# Map_Find= results_page.find_all('span', style='position: relative;')
# Rounds= results_page.find_all('div', class_='score')
# Date_Find= results_page.find_all('div', class_= 'moment-tz-convert')
# Patch_Find= results_page.find_all(class_= None)
# Event_Find= results_page.find_all('div', class_= 'match-header-super')

# Blank= driver.find_element(By.XPATH, '').text
Map= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[1]/div[2]/div[1]/span').text
Date= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[1]/div[1]/div[2]/div/div[1]').text

Patch= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[1]/div[1]/div[2]/div/div[3]/div').text
# Patch= 0
Event= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[1]/div[1]/div[1]/a/div/div[1]').text

Team1_Name_1 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[1]/div/a/div[1]').text
Team1_ACS_1 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[4]/span/span[1]').text
Team1_Kills_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[5]/span/span[1]').text
Team1_Deaths_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[6]/span/span[2]/span[1]').text
Team1_Assists_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[7]/span/span[1]').text
Team1_PlusMinus_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[8]/span/span[1]').text
Team1_KAST_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[9]/span/span[1]').text
Team1_ADR_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[10]/span/span[1]').text
Team1_FK_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[12]/span/span[1]').text
Team1_FD_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[13]/span/span[1]').text
Team1_FKFDPlusMinus_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[14]/span/span[1]').text

Team1_Name_2 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[1]/div/a/div[1]').text
Team1_ACS_2 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[4]/span/span[1]').text
Team1_Kills_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[5]/span/span[1]').text
Team1_Deaths_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[6]/span/span[2]/span[1]').text
Team1_Assists_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[7]/span/span[1]').text
Team1_PlusMinus_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[8]/span/span[1]').text
Team1_KAST_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[9]/span/span[1]').text
Team1_ADR_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[10]/span/span[1]').text
Team1_FK_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[12]/span/span[1]').text
Team1_FD_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[13]/span/span[1]').text
Team1_FKFDPlusMinus_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[14]/span/span[1]').text

Team1_Name_3 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[1]/div/a/div[1]').text
Team1_ACS_3 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[4]/span/span[1]').text
Team1_Kills_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[5]/span/span[1]').text
Team1_Deaths_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[6]/span/span[2]/span[1]').text
Team1_Assists_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[7]/span/span[1]').text
Team1_PlusMinus_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[8]/span/span[1]').text
Team1_KAST_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[9]/span/span[1]').text
Team1_ADR_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[10]/span/span[1]').text
Team1_FK_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[12]/span/span[1]').text
Team1_FD_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[13]/span/span[1]').text
Team1_FKFDPlusMinus_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[14]/span/span[1]').text

Team1_Name_4 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[1]/div/a/div[1]').text
Team1_ACS_4 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[4]/span/span[1]').text
Team1_Kills_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[5]/span/span[1]').text
Team1_Deaths_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[6]/span/span[2]/span[1]').text
Team1_Assists_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[7]/span/span[1]').text
Team1_PlusMinus_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[8]/span/span[1]').text
Team1_KAST_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[9]/span/span[1]').text
Team1_ADR_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[10]/span/span[1]').text
Team1_FK_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[12]/span/span[1]').text
Team1_FD_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[13]/span/span[1]').text
Team1_FKFDPlusMinus_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[14]/span/span[1]').text

Team1_Name_5 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[1]/div/a/div[1]').text
Team1_ACS_5 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[4]/span/span[1]').text
Team1_Kills_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[5]/span/span[1]').text
Team1_Deaths_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[6]/span/span[2]/span[1]').text
Team1_Assists_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[7]/span/span[1]').text
Team1_PlusMinus_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[8]/span/span[1]').text
Team1_KAST_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[9]/span/span[1]').text
Team1_ADR_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[10]/span/span[1]').text
Team1_FK_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[12]/span/span[1]').text
Team1_FD_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[13]/span/span[1]').text
Team1_FKFDPlusMinus_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[14]/span/span[1]').text

Team2_Name_1 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[1]/div/a/div[1]').text
Team2_ACS_1 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[4]/span/span[1]').text
Team2_Kills_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[5]/span/span[1]').text
Team2_Deaths_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[6]/span/span[2]/span[1]').text
Team2_Assists_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[7]/span/span[1]').text
Team2_PlusMinus_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[8]/span/span[1]').text
Team2_KAST_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[9]/span/span[1]').text
Team2_ADR_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[10]/span/span[1]').text
Team2_FK_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[12]/span/span[1]').text
Team2_FD_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[13]/span/span[1]').text
Team2_FKFDPlusMinus_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[14]/span/span[1]').text

Team2_Name_2 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[1]/div/a/div[1]').text
Team2_ACS_2 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[4]/span').text
Team2_Kills_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[5]/span/span[1]').text
Team2_Deaths_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[6]/span/span[2]/span[1]').text
Team2_Assists_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[7]/span/span[1]').text
Team2_PlusMinus_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[8]/span/span[1]').text
Team2_KAST_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[9]/span/span[1]').text
Team2_ADR_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[10]/span/span[1]').text
Team2_FK_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[12]/span/span[1]').text
Team2_FD_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[13]/span/span[1]').text
Team2_FKFDPlusMinus_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[14]/span/span[1]').text

Team2_Name_3 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[1]/div/a/div[1]').text
Team2_ACS_3 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[4]/span/span[1]').text
Team2_Kills_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[5]/span/span[1]').text
Team2_Deaths_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[6]/span/span[2]/span[1]').text
Team2_Assists_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[7]/span/span[1]').text
Team2_KAST_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[9]/span/span[1]').text
Team2_PlusMinus_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[8]/span/span[1]').text
Team2_ADR_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[10]/span/span[1]').text
Team2_FK_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[12]/span/span[1]').text
Team2_FD_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[13]/span/span[1]').text
Team2_FKFDPlusMinus_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[14]/span/span[1]').text

Team2_Name_4 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[1]/div/a/div[1]').text
Team2_ACS_4 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[4]/span/span[1]').text
Team2_Kills_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[5]/span/span[1]').text
Team2_Deaths_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[6]/span/span[2]/span[1]').text
Team2_Assists_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[7]/span/span[1]').text
Team2_PlusMinus_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[8]/span/span[1]').text
Team2_KAST_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[9]/span/span[1]').text
Team2_ADR_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[10]/span/span[1]').text
Team2_FK_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[12]/span/span[1]').text
Team2_FD_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[13]/span/span[1]').text
Team2_FKFDPlusMinus_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[14]/span/span[1]').text

Team2_Name_5 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[1]/div/a/div[1]').text
Team2_ACS_5 = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[4]/span/span[1]').text
Team2_Kills_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[5]/span/span[1]').text
Team2_Deaths_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[6]/span/span[2]/span[1]').text
Team2_Assists_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[7]/span/span[1]').text
Team2_PlusMinus_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[8]/span/span[1]').text
Team2_KAST_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[9]/span/span[1]').text
Team2_ADR_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[10]/span/span[1]').text
Team2_FK_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[12]/span/span[1]').text
Team2_FD_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[13]/span/span[1]').text
Team2_FKFDPlusMinus_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[14]/span/span[1]').text

Team1_Rounds_Won= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[1]/div[1]/div[1]').text
Team1_Rounds_Lost= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[1]/div[3]/div[2]').text
Team1_Opponent= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[1]/div[2]/a[2]/div/div[1]').text

Team2_Rounds_Won= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[1]/div[3]/div[2]').text
Team2_Rounds_Lost= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[1]/div[1]/div[1]').text
Team2_Opponent= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[1]/div[1]/div[2]/div').text

Team1_Rating_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[1]/td[3]/span/span[1]').text
Team1_Rating_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[2]/td[3]/span/span[1]').text
Team1_Rating_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[3]/td[3]/span/span[1]').text
Team1_Rating_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[4]/td[3]/span/span[1]').text
Team1_Rating_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[1]/table/tbody/tr[5]/td[3]/span/span[1]').text

Team2_Rating_1= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[1]/td[3]/span/span[1]').text
Team2_Rating_2= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[2]/td[3]/span/span[1]').text
Team2_Rating_3= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[3]/td[3]/span/span[1]').text
Team2_Rating_4= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[4]/td[3]/span/span[1]').text
Team2_Rating_5= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[6]/div/div[3]/div[1]/div[4]/div[2]/table/tbody/tr[5]/td[3]/span/span[1]').text

# team ratings are t wins
Team1_Rounds_Won_T= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[1]/div[2]/a[1]/div/div[2]').text
Team1_Rounds_Won_CT= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[2]/a/div/div[2]/span[4]').text
Team2_Rounds_Won_T= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[1]/div[2]/a[2]/div/div[2]').text
Team2_Rounds_Won_CT= driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[3]/div[2]/a/div/div[2]/span[4]').text
agents_array= []     
           
i = 0
parent_node= soup.findAll('tr')
for parent in parent_node:
    children= parent.findChildren('td', class_= 'mod-agents', recursive= False)
    for child in children:
        agent= child.findChildren('span', class_= 'stats-sq mod-agent small', recursive= True)
        agents_array.append(agent)
        i = i + 1

Team1_Agent1= agents_array[0]
Team1_Agent2= agents_array[1]
Team1_Agent3= agents_array[2]
Team1_Agent4= agents_array[3]
Team1_Agent5= agents_array[4]
Team2_Agent1= agents_array[5]
Team2_Agent2= agents_array[6]
Team2_Agent3= agents_array[7]
Team2_Agent4= agents_array[8]
Team2_Agent5= agents_array[9]

r_result= results_page.find_all('div', class_= 'vlr-rounds-row-col')

start= 0
start= int(start)

r1_result= r_result[start+1]
r2_result= r_result[start+2]
r3_result= r_result[start+3]
r4_result= r_result[start+4]
r5_result= r_result[start+5]
r6_result= r_result[start+6]
r7_result= r_result[start+7]
r8_result= r_result[start+8]
r9_result= r_result[start+9]
r10_result= r_result[start+10]
r11_result= r_result[start+11]
r12_result= r_result[start+12]
r13_result= r_result[start+14]
r14_result= r_result[start+15]
r15_result= r_result[start+16]
r16_result= r_result[start+17]
r17_result= r_result[start+18]
r18_result= r_result[start+19]
r19_result= r_result[start+20]
r20_result= r_result[start+21]
r21_result= r_result[start+22]
r22_result= r_result[start+23]
r23_result= r_result[start+24]
r24_result= r_result[start+25]

# r25_result= r_result[start+27]
# r26_result= r_result[start+28]
# r27_result= r_result[start+29]
# r28_result= r_result[start+30]
# r29_result= r_result[start+31]
# r30_result= r_result[start+32]
# r31_result= r_result[start+33]
# r32_result= r_result[start+34]
# r33_result= r_result[start+35]
# r34_result= r_result[start+36]
# r35_result= r_result[start+37]
# r36_result= r_result[start+38]
# r37_result= r_result[start+39]
# r38_result= r_result[start+40]
# r39_result= r_result[start+41]
# r40_result= r_result[start+42]
# r41_result= r_result[start+43]
# r42_result= r_result[start+44]
# r43_result= r_result[start+45]
# r44_result= r_result[start+46]
# r45_result= r_result[start+47]
# r46_result= r_result[start+48]

r25_result= 'N/A'
r26_result= 'N/A'
r27_result= 'N/A'
r28_result= 'N/A'
r29_result= 'N/A'
r30_result= 'N/A'
r31_result= 'N/A'
r32_result= 'N/A'
r33_result= 'N/A'
r34_result= 'N/A'
r35_result= 'N/A'
r36_result= 'N/A'
r37_result= 'N/A'
r38_result= 'N/A'
r39_result= 'N/A'
r40_result= 'N/A'
r41_result= 'N/A'
r42_result= 'N/A'
r43_result= 'N/A'
r44_result= 'N/A'
r45_result= 'N/A'
r46_result= 'N/A'

stats= {'Name': [Team1_Name_1, Team1_Name_2, Team1_Name_3, Team1_Name_4, Team1_Name_5, Team2_Name_1, Team2_Name_2, Team2_Name_3, Team2_Name_4, Team2_Name_5], 'Team': [Team2_Opponent, Team2_Opponent, Team2_Opponent, Team2_Opponent, Team2_Opponent, Team1_Opponent, Team1_Opponent, Team1_Opponent, Team1_Opponent, Team1_Opponent], 'Agent': [Team1_Agent1, Team1_Agent2, Team1_Agent3, Team1_Agent4, Team1_Agent5, Team2_Agent1, Team2_Agent2, Team2_Agent3, Team2_Agent4, Team2_Agent5], ' ACS': [Team1_ACS_1, Team1_ACS_2, Team1_ACS_3, Team1_ACS_4, Team1_ACS_5, Team2_ACS_1, Team2_ACS_2, Team2_ACS_3, Team2_ACS_4, Team2_ACS_5], 'Kills': [Team1_Kills_1, Team1_Kills_2, Team1_Kills_3, Team1_Kills_4, Team1_Kills_5, Team2_Kills_1, Team2_Kills_2, Team2_Kills_3, Team2_Kills_4, Team2_Kills_5], 'Deaths': [Team1_Deaths_1, Team1_Deaths_2, Team1_Deaths_3, Team1_Deaths_4, Team1_Deaths_5, Team2_Deaths_1, Team2_Deaths_2, Team2_Deaths_3, Team2_Deaths_4, Team2_Deaths_5], 'Assists': [Team1_Assists_1, Team1_Assists_2, Team1_Assists_3, Team1_Assists_4, Team1_Assists_5, Team2_Assists_1, Team2_Assists_2, Team2_Assists_3, Team2_Assists_4, Team2_Assists_5], 'PlusMinus': [Team1_PlusMinus_1, Team1_PlusMinus_2, Team1_PlusMinus_3, Team1_PlusMinus_4, Team1_PlusMinus_5, Team2_PlusMinus_1, Team2_PlusMinus_2, Team2_PlusMinus_3, Team2_PlusMinus_4, Team2_PlusMinus_5], 'KAST': [Team1_KAST_1, Team1_KAST_2, Team1_KAST_3, Team1_KAST_4, Team1_KAST_5, Team2_KAST_1, Team2_KAST_2, Team2_KAST_3, Team2_KAST_4, Team2_KAST_5], 'ADR': [Team1_ADR_1, Team1_ADR_2, Team1_ADR_3, Team1_ADR_4, Team1_ADR_5, Team2_ADR_1, Team2_ADR_2, Team2_ADR_3, Team2_ADR_4, Team2_ADR_5], 'FK': [Team1_FK_1, Team1_FK_2, Team1_FK_3, Team1_FK_4, Team1_FK_5, Team2_FK_1, Team2_FK_2, Team2_FK_3, Team2_FK_4, Team2_FK_5], 'FD': [Team1_FD_1, Team1_FD_2, Team1_FD_3, Team1_FD_4, Team1_FD_5, Team2_FD_1, Team2_FD_2, Team2_FD_3, Team2_FD_4, Team2_FD_5], 'FKFDPlusMinus': [Team1_FKFDPlusMinus_1, Team1_FKFDPlusMinus_2, Team1_FKFDPlusMinus_3, Team1_FKFDPlusMinus_4, Team1_FKFDPlusMinus_5, Team2_FKFDPlusMinus_1, Team2_FKFDPlusMinus_2, Team2_FKFDPlusMinus_3, Team2_FKFDPlusMinus_4, Team2_FKFDPlusMinus_5], 'Map': [Map, Map, Map, Map, Map, Map, Map, Map, Map, Map], 'Opponent': [Team1_Opponent, Team1_Opponent, Team1_Opponent, Team1_Opponent, Team1_Opponent, Team2_Opponent, Team2_Opponent, Team2_Opponent, Team2_Opponent, Team2_Opponent], 'Date': [Date, Date, Date, Date, Date, Date, Date, Date, Date, Date], 'Patch': [Patch, Patch, Patch, Patch, Patch, Patch, Patch, Patch, Patch, Patch], 'Event': [Event, Event, Event, Event, Event, Event, Event, Event, Event, Event], 'Rounds Won': [Team1_Rounds_Won, Team1_Rounds_Won, Team1_Rounds_Won, Team1_Rounds_Won, Team1_Rounds_Won, Team2_Rounds_Won, Team2_Rounds_Won, Team2_Rounds_Won, Team2_Rounds_Won, Team2_Rounds_Won], 'Rounds Won CT': [Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT], 'Rounds Won T': [Team1_Rounds_Won_T, Team1_Rounds_Won_T, Team1_Rounds_Won_T, Team1_Rounds_Won_T, Team1_Rounds_Won_T, Team2_Rounds_Won_T, Team2_Rounds_Won_T, Team2_Rounds_Won_T, Team2_Rounds_Won_T, Team2_Rounds_Won_T], 'Rounds Lost': [Team1_Rounds_Lost, Team1_Rounds_Lost, Team1_Rounds_Lost, Team1_Rounds_Lost, Team1_Rounds_Lost, Team2_Rounds_Lost, Team2_Rounds_Lost, Team2_Rounds_Lost, Team2_Rounds_Lost, Team2_Rounds_Lost],'Rounds Lost CT': [Team1_Rating_1, Team1_Rating_2, Team1_Rating_3, Team1_Rating_4, Team1_Rating_5, Team2_Rating_1, Team2_Rating_2, Team2_Rating_3, Team2_Rating_4, Team2_Rating_5], 'Rounds Lost T': [Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team2_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT, Team1_Rounds_Won_CT], 'Round 1 Result': [r1_result, r1_result, r1_result, r1_result, r1_result, r1_result, r1_result, r1_result, r1_result, r1_result], 'Round 2 Result': [r2_result, r2_result, r2_result, r2_result, r2_result, r2_result, r2_result, r2_result, r2_result, r2_result], 'Round 3 Result': [r3_result, r3_result, r3_result, r3_result, r3_result, r3_result, r3_result, r3_result, r3_result, r3_result], 'Round 4 Result': [r4_result, r4_result, r4_result, r4_result, r4_result, r4_result, r4_result, r4_result, r4_result, r4_result], 'Round 5 Result': [r5_result, r5_result, r5_result, r5_result, r5_result, r5_result, r5_result, r5_result, r5_result, r5_result], 'Round 6 Result': [r6_result, r6_result, r6_result, r6_result, r6_result, r6_result, r6_result, r6_result, r6_result, r6_result], 'Round 7 Result': [r7_result, r7_result, r7_result, r7_result, r7_result, r7_result, r7_result, r7_result, r7_result, r7_result], 'Round 8 Result': [r8_result, r8_result, r8_result, r8_result, r8_result, r8_result, r8_result, r8_result, r8_result, r8_result], 'Round 9 Result': [r9_result, r9_result, r9_result, r9_result, r9_result, r9_result, r9_result, r9_result, r9_result, r9_result], 'Round 10 Result': [r10_result, r10_result, r10_result, r10_result, r10_result, r10_result, r10_result, r10_result, r10_result, r10_result], 'Round 11 Result': [r11_result, r11_result, r11_result, r11_result, r11_result, r11_result, r11_result, r11_result, r11_result, r11_result], 'Round 12 Result': [r12_result, r12_result, r12_result, r12_result, r12_result, r12_result, r12_result, r12_result, r12_result, r12_result], 'Round 13 Result': [r13_result, r13_result, r13_result, r13_result, r13_result, r13_result, r13_result, r13_result, r13_result, r13_result], 'Round 14 Result': [r14_result, r14_result, r14_result, r14_result, r14_result, r14_result, r14_result, r14_result, r14_result, r14_result], 'Round 15 Result': [r15_result, r15_result, r15_result, r15_result, r15_result, r15_result, r15_result, r15_result, r15_result, r15_result], 'Round 16 Result': [r16_result, r16_result, r16_result, r16_result, r16_result, r16_result, r16_result, r16_result, r16_result, r16_result], 'Round 17 Result': [r17_result, r17_result, r17_result, r17_result, r17_result, r17_result, r17_result, r17_result, r17_result, r17_result], 'Round 18 Result': [r18_result, r18_result, r18_result, r18_result, r18_result, r18_result, r18_result, r18_result, r18_result, r18_result], 'Round 19 Result': [r19_result, r19_result, r19_result, r19_result, r19_result, r19_result, r19_result, r19_result, r19_result, r19_result], 'Round 20 Result': [r20_result, r20_result, r20_result, r20_result, r20_result, r20_result, r20_result, r20_result, r20_result, r20_result], 'Round 21 Result': [r21_result, r21_result, r21_result, r21_result, r21_result, r21_result, r21_result, r21_result, r21_result, r21_result], 'Round 22 Result': [r22_result, r22_result, r22_result, r22_result, r22_result, r22_result, r22_result, r22_result, r22_result, r22_result], 'Round 23 Result': [r23_result, r23_result, r23_result, r23_result, r23_result, r23_result, r23_result, r23_result, r23_result, r23_result], 'Round 24 Result': [r24_result, r24_result, r24_result, r24_result, r24_result, r24_result, r24_result, r24_result, r24_result, r24_result], 
        'Round 25 Result': [r25_result, r25_result, r25_result, r25_result, r25_result, r25_result, r25_result, r25_result, r25_result, r25_result], 
        'Round 26 Result': [r26_result, r26_result, r26_result, r26_result, r26_result, r26_result, r26_result, r26_result, r26_result, r26_result], 
        'Round 27 Result': [r27_result, r27_result, r27_result, r27_result, r27_result, r27_result, r27_result, r27_result, r27_result, r27_result], 
        'Round 28 Result': [r28_result, r28_result, r28_result, r28_result, r28_result, r28_result, r28_result, r28_result, r28_result, r28_result], 
        'Round 29 Result': [r29_result, r29_result, r29_result, r29_result, r29_result, r29_result, r29_result, r29_result, r29_result, r29_result], 
        'Round 30 Result': [r30_result, r30_result, r30_result, r30_result, r30_result, r30_result, r30_result, r30_result, r30_result, r30_result], 
        'Round 31 Result': [r31_result, r31_result, r31_result, r31_result, r31_result, r31_result, r31_result, r31_result, r31_result, r31_result], 
        'Round 32 Result': [r32_result, r32_result, r32_result, r32_result, r32_result, r32_result, r32_result, r32_result, r32_result, r32_result], 
        'Round 33 Result': [r33_result, r33_result, r33_result, r33_result, r33_result, r33_result, r33_result, r33_result, r33_result, r33_result], 
        'Round 34 Result': [r34_result, r34_result, r34_result, r34_result, r34_result, r34_result, r34_result, r34_result, r34_result, r34_result], 
        'Round 35 Result': [r35_result, r35_result, r35_result, r35_result, r35_result, r35_result, r35_result, r35_result, r35_result, r35_result], 
        'Round 36 Result': [r36_result, r36_result, r36_result, r36_result, r36_result, r36_result, r36_result, r36_result, r36_result, r36_result], 
        'Round 37 Result': [r37_result, r37_result, r37_result, r37_result, r37_result, r37_result, r37_result, r37_result, r37_result, r37_result], 
        'Round 38 Result': [r38_result, r38_result, r38_result, r38_result, r38_result, r38_result, r38_result, r38_result, r38_result, r38_result], 
        'Round 39 Result': [r39_result, r39_result, r39_result, r39_result, r39_result, r39_result, r39_result, r39_result, r39_result, r39_result], 
        'Round 40 Result': [r40_result, r40_result, r40_result, r40_result, r40_result, r40_result, r40_result, r40_result, r40_result, r40_result], 
        'Round 41 Result': [r41_result, r41_result, r41_result, r41_result, r41_result, r41_result, r41_result, r41_result, r41_result, r41_result], 
        'Round 42 Result': [r42_result, r42_result, r42_result, r42_result, r42_result, r42_result, r42_result, r42_result, r42_result, r42_result], 
        'Round 43 Result': [r43_result, r43_result, r43_result, r43_result, r43_result, r43_result, r43_result, r43_result, r43_result, r43_result], 
        'Round 44 Result': [r44_result, r44_result, r44_result, r44_result, r44_result, r44_result, r44_result, r44_result, r44_result, r44_result], 
        'Round 45 Result': [r45_result, r45_result, r45_result, r45_result, r45_result, r45_result, r45_result, r45_result, r45_result, r45_result], 
        'Round 46 Result': [r46_result, r46_result, r46_result, r46_result, r46_result, r46_result, r46_result, r46_result, r46_result, r46_result]
       }

df= pd.DataFrame(data=stats)
df.set_index('Name', inplace=True)
df.to_csv('C:/Users/sahrw/OneDrive/Desktop/1229.csv')
# Out:
# Enter match map link:  https://www.vlr.gg/378829/edward-gaming-vs-team-heretics-valorant-champions-2024-gf/?game=180435&tab=overview
